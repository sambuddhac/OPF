# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.loadtxt('itresult.txt')
y = np.loadtxt('dualresult.txt')
z = np.loadtxt('primresult.txt')
plt.plot(x,y,z, label='Primal & Dual Residual versus Iteration')
plt.xlabel('Number of Iterations')
plt.ylabel('Primal & Dual Residual')
plt.title('Primal & Dual Residual versus Iteration')
# Out:
# Text(0.5, 1.0, 'Primal & Dual Residual versus Iteration')
